# %% [markdown]
# # Identify Camera Trap Arrays with all sites within 5km and Full data for 5 years

# %%
import pandas as pd 
import numpy as np 
import warnings 
from tabulate import tabulate
from itertools import combinations
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %%
data_dir = r'/Users/neelima/Documents/ML_Projects/data'
out_dir = r'/Users/neelima/Documents/ML_Projects/output'

# %%
camera_trap_dis_threshold = 5

# %%
array_proximity_with_year_df = pd.read_csv(out_dir + r'/camera_array_5km_proximity_sites.csv')
array_proximity_with_year_df.shape
# Out:
# (591, 5)

# %%
array_proximity_with_year_df.columns
# Out:
# Index(['Camera_Trap_Array', 'Year', 'Mean_Latitude', 'Mean_Longitude',
#        'Proximity_List'],
#       dtype='object')

# %%
# Unique Camera trap array elements count 
array_proximity_with_year_df['Camera_Trap_Array'].nunique()
# Out:
# 262

# %%
array_proximity_with_year_df.head()
# Out:
#   Camera_Trap_Array  Year  Mean_Latitude  Mean_Longitude  \
# 0             ARNWR  2020        35.8094        -75.9057
# 1             ARNWR  2021        35.8236        -75.8931
# 2             ARNWR  2022        35.8263        -75.8911
# 3             AandM  2022        26.2209        -97.4273
# 4           Abilene  2019        32.2393        -99.8829
#
#                                       Proximity_List
# 0  {'NC_Forest_Alligator_River_NWR_20_03', 'NC_Fo...
# 1  {'NC_Wetland_ARNWR_21_dep_15', 'NC_Wetland_ARN...
# 2  {'NC_Wetland_ARNWR_22_Cam07', 'NC_Wetland_ARNW...
# 3  {'TX_Shrubland_A&M_CCR002', 'TX_Shrubland_A&M_...
# 4  {'TX_Grassland_Abilene_13B', 'TX_Grassland_Abi...

# %% [markdown]
# ### Find Camera Trap Arrays that have complete data

# %%
#write code to extract camera trap array names that have complete data for given set of years required 
# make sure the array_proximity_with_year_df has data for all the years specified in the years list 
def array_with_years_data(array_proximity_with_year_df, years):
    
    """
    Get camera trap arrays that have data for all specified years.
    
    :param array_proximity_with_year_df: DataFrame containing camera trap array data with years
    :param years: List of years to check
    :return: List of camera trap arrays with complete data for specified years
    """
    # Filter the DataFrame for the specified years
    filtered_df = array_proximity_with_year_df[array_proximity_with_year_df['Year'].isin(years)]
    
    # Group by Camera Trap Array and count unique years
    grouped = filtered_df.groupby('Camera_Trap_Array')['Year'].nunique()
    
    # Return arrays that have data for all specified years
    return grouped[grouped == len(years)].index.tolist()

# %%
# call function get_arrays_with_years for period of 2 , 3, 4 and 5 years starting 2019
# extract the camera trap array names and store in separate csv file 
# each number of years will be in separate csv file
# For example, for 2 years, the file will be named camera_trap_arrays_with_2_years.csv
# use only one for loop to iterate through the years list
years_list = [2, 3, 4, 5]

start_year = 2019
for years in years_list:
    
    end_year = start_year + years - 1
    years_range = list(range(start_year, end_year + 1))
    
    # Get camera trap arrays with complete data for the specified years
    arrays_with_years = array_with_years_data(array_proximity_with_year_df, years_range)
    
    # Store the arrays in a DataFrame and save to CSV
    df = pd.DataFrame(arrays_with_years, columns=['Camera_Trap_Array'])
    print(f'Total arrays with data for {years} years: {len(arrays_with_years)}')
    df.to_csv(out_dir + f'/arrays_years/camera_arrays_{years}_years.csv', index=False)
# Out:
# Total arrays with data for 2 years: 61
# Total arrays with data for 3 years: 50
# Total arrays with data for 4 years: 45
# Total arrays with data for 5 years: 43

# %%
years_required = set(range(2019, 2021))
#print(years_required, "Required Years List")

# collect sets of years for each camera trap array
camera_arrays_with_years = array_proximity_with_year_df.groupby('Camera_Trap_Array')['Year'].apply(set)

camera_arrays_all_years = camera_arrays_with_years[camera_arrays_with_years.apply(
    lambda years: years_required.issubset(years))
]

arrays_with_all_years_list = camera_arrays_all_years.index.tolist()
len(arrays_with_all_years_list)
# Out:
# {2019, 2020} Required Years List
# 61

# %%
#arrays_all_years_data = array_distances_with_year_df[array_distances_with_year_df['Camera_Trap_Array'].isin(arrays_with_all_years_list)]
arrays_all_years_data_df = array_proximity_with_year_df[array_distances_with_year_df['Camera_Trap_Array'].isin(arrays_with_all_years_list)]

# %%
arrays_all_years_data_df.shape
# Out:
# (216, 5)

# %%
arrays_all_years_data_df['Camera_Trap_Array'].nunique()
# Out:
# 43

# %%
arrays_all_years_data_df.head(20)
# Out:
#    Camera_Trap_Array  Year  Mean_Latitude  Mean_Longitude  \
# 4            Abilene  2019        32.2393        -99.8829
# 5            Abilene  2020        32.2383        -99.8839
# 6            Abilene  2021        32.2374        -99.8833
# 7            Abilene  2022        32.2364        -99.8847
# 8            Abilene  2023        32.2379        -99.8841
# 20          Angelina  2019        31.5007        -94.7791
# 21          Angelina  2020        31.4999        -94.7760
# 22          Angelina  2021        31.5005        -94.7783
# 23          Angelina  2022        31.5156        -94.7727
# 24          Angelina  2023        31.5007        -94.7790
# 29           Ardmore  2019        34.0068        -97.2381
# 30           Ardmore  2020        34.0077        -97.2387
# 31           Ardmore  2021        34.0065        -97.2385
# 32           Ardmore  2022        34.0061        -97.2361
# 33           Ardmore  2023        34.0051        -97.2358
# 40             Baggs  2019        41.2716       -107.6542
# 41             Baggs  2020        41.2716       -107.6535
# 42             Baggs  2021        41.2713       -107.6537
# 43             Baggs  2022        41.2757       -107.6521
# 44             Baggs  2023        41.2757       -107.6521
#
#                                        Proximity_List
# 4   {'TX_Grassland_Abilene_13B', 'TX_Grassland_Abi...
# 5   {'TX_Grassland_Abilene_20_05', 'TX_Grassland_A...
# 6   {'Abilene State Park Texas 6', 'Abilene State ...
# 7   {'TX_Grassland_Abilene_22_3', 'TX_Grassland_Ab...
# 8   {'TX_Grassland_Abilene State Park Texas 09/02/...
# 20  {'TX_Forest_Pineywoods_Angelina_1', 'TX_Forest...
# 21  {'TX_Forest_Pineywoods_Angelina_20_04', 'TX_Fo...
# 22  {'TX_Forest_Pineywoods_Angelina_14 10/08/2021'...
# 23  {'TX_Forest_Angelina_ANF_CAM16', 'TX_Forest_An...
# 24  {'TX_Forest_Rural_Angelina_23_loc10_dep10', 'T...
# 29  {'OK_Grassland_Ardmore_2', 'OK_Grassland_Ardmo...
# 30  {'OK_Grassland_Ardmore_03', 'OK_Grassland_Ardm...
# 31  {'OK_Grassland_Ardmore_21_Loc16_Oct2021', 'OK_...
# 32  {'OK_Grassland_Ardmore_22_01', 'OK_Grassland_A...
# 33  {'OK_Grassland_Ardmore_23_09', 'OK_Grassland_A...
# 40  {'WY_Grassland_Carbon_County_10', 'WY_Grasslan...
# 41  {'WY_Grassland_Carbon_County_20_06', 'WY_Grass...
# 42  {'Baggs_Wild_Grasslands_21_dep_01_USE', 'Baggs...
# 43  {'WY_grassland_wild_Baggs_22_Deployment12', 'W...
# 44  {'WY_Grassland_Wild_Baggs_23_Location7', 'WY_G...

# %%
output_path = out_dir + r'/camera_array_5km_proximity_all_years.csv'
arrays_all_years_data_df[['Camera_Trap_Array','Year','Mean_Latitude','Mean_Longitude','Proximity_List'] ].to_csv(output_path, index=False)

# %%
arrays_all_years_data_df.head(50)
# Out:
#    Camera_Trap_Array  Year  Mean_Latitude  Mean_Longitude  \
# 4            Abilene  2019        32.2393        -99.8829
# 5            Abilene  2020        32.2383        -99.8839
# 6            Abilene  2021        32.2374        -99.8833
# 7            Abilene  2022        32.2364        -99.8847
# 8            Abilene  2023        32.2379        -99.8841
# 20          Angelina  2019        31.5007        -94.7791
# 21          Angelina  2020        31.4999        -94.7760
# 22          Angelina  2021        31.5005        -94.7783
# 23          Angelina  2022        31.5156        -94.7727
# 24          Angelina  2023        31.5007        -94.7790
# 29           Ardmore  2019        34.0068        -97.2381
# 30           Ardmore  2020        34.0077        -97.2387
# 31           Ardmore  2021        34.0065        -97.2385
# 32           Ardmore  2022        34.0061        -97.2361
# 33           Ardmore  2023        34.0051        -97.2358
# 40             Baggs  2019        41.2716       -107.6542
# 41             Baggs  2020        41.2716       -107.6535
# 42             Baggs  2021        41.2713       -107.6537
# 43             Baggs  2022        41.2757       -107.6521
# 44             Baggs  2023        41.2757       -107.6521
# 58             Bogan  2019        42.7167        -73.8575
# 59             Bogan  2020        42.7169        -73.8580
# 60             Bogan  2021        42.7167        -73.8577
# 61             Bogan  2022        42.7164        -73.8575
# 62             Bogan  2023        42.7165        -73.8578
# 63             Bogan  2024        42.7197        -73.8559
# 68  BridgewaterState  2019        41.9860        -70.9585
# 69  BridgewaterState  2020        41.9860        -70.9586
# 70  BridgewaterState  2021        41.9861        -70.9583
# 71  BridgewaterState  2022        41.9857        -70.9584
# 72  BridgewaterState  2023        41.9860        -70.9584
# 73            Brooke  2019        40.4258        -86.9598
# 74            Brooke  2020        40.4257        -86.9605
# 75            Brooke  2021        40.4252        -86.9616
# 76            Brooke  2022        40.4252        -86.9616
# 77            Brooke  2023        40.4259        -86.9617
# 78         Brookings  2019        44.3308        -96.8169
# 79         Brookings  2020        44.3346        -96.8083
# 80         Brookings  2021        44.3302        -96.8152
# 81         Brookings  2022        44.3338        -96.8078
# 82         Brookings  2023        44.3343        -96.8108
# 84        BullShoals  2019        36.5684        -93.0691
# 85        BullShoals  2020        36.5688        -93.0707
# 86        BullShoals  2021        36.5689        -93.0696
# 87        BullShoals  2022        36.5686        -93.0686
# 88        BullShoals  2023        36.5691        -93.0709
# 90       Burneyville  2019        33.9288        -97.2272
# 91       Burneyville  2020        33.9283        -97.2274
# 92       Burneyville  2021        33.9283        -97.2274
# 93       Burneyville  2022        33.9281        -97.2251
#
#                                        Proximity_List
# 4   {'TX_Grassland_Abilene_13B', 'TX_Grassland_Abi...
# 5   {'TX_Grassland_Abilene_20_05', 'TX_Grassland_A...
# 6   {'Abilene State Park Texas 6', 'Abilene State ...
# 7   {'TX_Grassland_Abilene_22_3', 'TX_Grassland_Ab...
# 8   {'TX_Grassland_Abilene State Park Texas 09/02/...
# 20  {'TX_Forest_Pineywoods_Angelina_1', 'TX_Forest...
# 21  {'TX_Forest_Pineywoods_Angelina_20_04', 'TX_Fo...
# 22  {'TX_Forest_Pineywoods_Angelina_14 10/08/2021'...
# 23  {'TX_Forest_Angelina_ANF_CAM16', 'TX_Forest_An...
# 24  {'TX_Forest_Rural_Angelina_23_loc10_dep10', 'T...
# 29  {'OK_Grassland_Ardmore_2', 'OK_Grassland_Ardmo...
# 30  {'OK_Grassland_Ardmore_03', 'OK_Grassland_Ardm...
# 31  {'OK_Grassland_Ardmore_21_Loc16_Oct2021', 'OK_...
# 32  {'OK_Grassland_Ardmore_22_01', 'OK_Grassland_A...
# 33  {'OK_Grassland_Ardmore_23_09', 'OK_Grassland_A...
# 40  {'WY_Grassland_Carbon_County_10', 'WY_Grasslan...
# 41  {'WY_Grassland_Carbon_County_20_06', 'WY_Grass...
# 42  {'Baggs_Wild_Grasslands_21_dep_01_USE', 'Baggs...
# 43  {'WY_grassland_wild_Baggs_22_Deployment12', 'W...
# 44  {'WY_Grassland_Wild_Baggs_23_Location7', 'WY_G...
# 58  {'NY_Forest_Albany_Pine_Bush_1', 'NY_Forest_Al...
# 59  {'NY_Forest_Albany_Pine_Bush_20_03', 'NY_Fores...
# 60  {'NY_Forest_Bogan_21_Dep_09', 'NY_Forest_Bogan...
# 61  {'NY_Forest_Bogan_22_Dep_14', 'NY_Forest_Bogan...
# 62  {'NY_Forest_Bogan_23_Dep_14', 'NY_Forest_Bogan...
# 63                                              set()
# 68  {'MA_Forest_Bridgewater_State_University_6', '...
# 69  {'MA_Forest_Bridgewater_State_University_20_03...
# 70  {'MA_Forest_BridgewaterState_21_PurplePine 08/...
# 71  {'MA_Forest_BridgewaterState_22_GHRoad_Cam12',...
# 72  {'MA_Forest_Suburban_BridgewaterStateUniversit...
# 73  {'IN_Forest_Purdue_Lugar_3', 'IN_Forest_Purdue...
# 74  {'IN_Forest_Purdue_Lugar_20_01', 'IN_Forest_Pu...
# 75  {'IN_Purdue_Brooke_21_5', 'IN_Purdue_Brooke_21...
# 76  {'IN_Forest_Purdue_Brooke_22_Lugar8_20220909',...
# 77  {'IN_Forest_Rural_Brooke__23_loc_05', 'IN_Fore...
# 78  {'SD_Shelterbelt_and_Grassland_Brookings_1', '...
# 79  {'SD_Shelterbelt_and_Grassland_Brookings_20_04...
# 80  {'SD_Shelterbelt_and_Grasslands_Brookings_C10 ...
# 81  {'SD_Grasslands_Brookings_22_13', 'SD_Grasslan...
# 82  {'SD_Grassland_Suburban_Brookings_23_C05', 'SD...
# 84  {'MO_Forest_Bull_Shoals_6', 'MO_Forest_Bull_Sh...
# 85  {'MO_Forest_Bull_Shoals_20_05', 'MO_Forest_Bul...
# 86  {'MO_Forest_BullShoals_21_02b', 'MO_Forest_Bul...
# 87  {'MO_Forest_BullShoals_22_Cam03 09/03/2022', '...
# 88  {'MO_Forest_BullShoals_22_Cam11 09/01/2023', '...
# 90  {'OK_Grassland_Burneyville_2', 'OK_Grassland_B...
# 91  {'OK_Grassland_Burneyville_02', 'OK_Grassland_...
# 92  {'OK_Grassland_Burneyville_21_Loc01_Sept2021',...
# 93  {'OK_Grassland_Burneyville_22_13', 'OK_Grassla...
