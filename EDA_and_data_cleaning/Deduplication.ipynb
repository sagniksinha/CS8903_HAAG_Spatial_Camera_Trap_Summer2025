# %%
import pandas as pd
import os
from datetime import timedelta

# %%
save_dir = r'data\ssusa'
os.makedirs(save_dir, exist_ok=True)

# %%
# Define the directory path
data_dir = save_dir

# Define file paths
sequences_path = data_dir + r'\ssusa_finalsequences.csv'

# %%
sequences_df = pd.read_csv(
    sequences_path,
    na_values=["NA", " "],
    dtype={
        "Year": "Int64",
        "Sequence_ID": "object",
        "Group_Size": "Int64",
    },
    keep_default_na=True,
    parse_dates=["Start_Time", "End_Time"]
)
print(f"Number of records in sequences_df: {len(sequences_df)}")
# Out:
# Number of records in sequences_df: 987979

# %%
sequences_df = sequences_df[sequences_df['Class'] == 'Mammalia']

# %%
# Columns to convert to Proper Case
prop_case_cols = [
    'Class', 'Order', 'Family', 'Genus', 'Species', 'Common_Name', 'Age', 'Sex'
]

# First, replace blank or whitespace-only strings with NaN for Age, Sex, and Group_Size
sequences_df[['Age', 'Sex', 'Group_Size']] = sequences_df[['Age', 'Sex', 'Group_Size']].replace(r'^\s*$', pd.NA, regex=True)

# Group_Size: Replace missing with 0 and convert to numeric
sequences_df['Group_Size'] = sequences_df['Group_Size'].fillna(0)
sequences_df['Group_Size'] = pd.to_numeric(sequences_df['Group_Size'], errors='coerce').fillna(0).astype(int)

# Age and Sex: Replace missing with 'Unknown'
sequences_df['Age'] = sequences_df['Age'].fillna('Unknown')
sequences_df['Sex'] = sequences_df['Sex'].fillna('Unknown')

# Now apply proper case to selected columns
for col in prop_case_cols:
    sequences_df[col] = sequences_df[col].str.lower()

# %%
def find_close_duplicates(group, minutes=5):
    idx = []
    interval = timedelta(minutes=minutes)
    for i in range(len(group)):
        start = group.iloc[i]['Start_Time']
        common_name = group.iloc[i]['Common_Name']
        # Only compare rows with the same Common_Name
        same_name = group['Common_Name'] == common_name
        mask = (
            (
                ((group['Start_Time'] >= start - interval) & (group['Start_Time'] <= start + interval)) |
                ((group['End_Time'] >= start - interval) & (group['End_Time'] <= start + interval))
            ) & same_name
        )
        # Exclude self
        mask.iloc[i] = False
        if mask.any():
            idx.append(group.index[i])
    return idx

# %%
# from datetime import timedelta

# # Sort by Deployment_ID and Start_Time
# sequences_df_sorted = sequences_df.sort_values(['Deployment_ID', 'Start_Time'])

# # For each row, check if there is another row within 5 minutes in the same Deployment_ID
# def find_close_duplicates(group):
#     idx = []
#     for i in range(len(group)):
#         start = group.iloc[i]['Start_Time']
#         # Check if any other row's Start_Time or End_Time is within 5 minutes
#         mask = (
#             ((group['Start_Time'] >= start - timedelta(minutes=5)) & (group['Start_Time'] <= start + timedelta(minutes=5))) |
#             ((group['End_Time'] >= start - timedelta(minutes=5)) & (group['End_Time'] <= start + timedelta(minutes=5)))
#         )
#         # Exclude self
#         mask.iloc[i] = False
#         if mask.any():
#             idx.append(group.index[i])
#     return idx

# close_dup_idx = []
# for _, group in sequences_df_sorted.groupby('Deployment_ID'):
#     close_dup_idx.extend(find_close_duplicates(group))

# close_duplicates = sequences_df.loc[close_dup_idx]
# print(f"Number of 5 mins duplicate = {len(close_duplicates)}")

# %%
intervals = [1, 5, 10, 15, 30, 60]  # in minutes
all_close_dup_idx = {}
all_close_duplicates = {}
sequences_df_sorted = sequences_df.sort_values(['Deployment_ID', 'Start_Time'])

for mins in intervals:
    close_dup_idx = []
    for _, group in sequences_df_sorted.groupby('Deployment_ID'):
        close_dup_idx.extend(find_close_duplicates(group, minutes=mins))
    all_close_dup_idx[mins] = close_dup_idx
    all_close_duplicates[mins] = sequences_df.loc[close_dup_idx]
    print(f"Interval: {mins} min, Number of duplicates: {len(close_dup_idx)}")
    display(all_close_duplicates[mins].head())
# Out:
# Interval: 1 min, Number of duplicates: 43707
#         Year            Project Camera_Trap_Array  \
# 607528  2022  Snapshot USA 2022           Afognak
# 571610  2022  Snapshot USA 2022           Afognak
# 569901  2022  Snapshot USA 2022           Afognak
# 3       2019  Snapshot USA 2019             Crupi
# 4       2019  Snapshot USA 2019             Crupi
#
#                                  Deployment_ID Sequence_ID  \
# 607528             AK_Forest_Afognak_22_C22-16     2978537
# 571610  AK_Forest_Afognak_22_C22-18 08/31/2022     2985790
# 569901  AK_Forest_Afognak_22_C22-57 09/01/2022     2988518
# 3                 AK_Forest_Chilkat_Preserve_1    d58722s4
# 4                 AK_Forest_Chilkat_Preserve_1    d58722s4
#
#                 Start_Time            End_Time     Class            Order  \
# 607528 2022-09-10 02:12:12 2022-09-10 02:12:38  mammalia       lagomorpha
# 571610 2022-09-03 19:45:55 2022-09-03 19:45:57  mammalia  cetartiodactyla
# 569901 2022-09-12 07:19:50 2022-09-12 07:20:35  mammalia  cetartiodactyla
# 3      2019-08-31 20:58:00 2019-08-31 20:58:00  mammalia        carnivora
# 4      2019-08-31 20:58:00 2019-08-31 20:58:00  mammalia        carnivora
#
#            Family       Genus     Species    Common_Name       Age      Sex  \
# 607528  leporidae       lepus  americanus  snowshoe hare   unknown  unknown
# 571610   cervidae  odocoileus    hemionus      mule deer   unknown  unknown
# 569901   cervidae  odocoileus    hemionus      mule deer   unknown  unknown
# 3         ursidae       ursus      arctos     brown bear     adult   female
# 4         ursidae       ursus      arctos     brown bear  juvenile  unknown
#
#         Group_Size
# 607528           1
# 571610           1
# 569901           1
# 3                1
# 4                2
# Interval: 5 min, Number of duplicates: 241400
#         Year            Project Camera_Trap_Array            Deployment_ID  \
# 977986  2023  Snapshot USA 2023       CoteauRanch  7CoteauRanch 09/30/2023
# 977987  2023  Snapshot USA 2023       CoteauRanch  7CoteauRanch 09/30/2023
# 978000  2023  Snapshot USA 2023       CoteauRanch  8CoteauRanch 09/30/2023
# 978006  2023  Snapshot USA 2023       CoteauRanch  8CoteauRanch 09/30/2023
# 978005  2023  Snapshot USA 2023       CoteauRanch  8CoteauRanch 09/30/2023
#
#        Sequence_ID          Start_Time            End_Time     Class  \
# 977986     8477867 2023-10-15 15:53:51 2023-10-15 15:53:51  mammalia
# 977987     8477868 2023-10-15 15:57:15 2023-10-15 15:57:15  mammalia
# 978000     8477881 2023-10-13 19:00:36 2023-10-13 19:00:40  mammalia
# 978006     8477882 2023-10-13 19:05:18 2023-10-13 19:05:28  mammalia
# 977995     8477880 2023-10-12 15:23:05 2023-10-12 15:23:06  mammalia
# 978000     8477881 2023-10-13 19:00:36 2023-10-13 19:00:40  mammalia
#
#                   Order    Family       Genus   Species      Common_Name  \
# 977986  cetartiodactyla   bovidae         bos    taurus  domestic cattle
# 977987  cetartiodactyla   bovidae         bos    taurus  domestic cattle
# 977994        carnivora   canidae       canis   latrans           coyote
# 977995        carnivora   canidae       canis   latrans           coyote
# 978000  cetartiodactyla  cervidae  odocoileus  hemionus        mule deer
#
#             Age      Sex  Group_Size
# 977986  unknown  unknown           2
# 977987  unknown  unknown           3
# 977994  unknown  unknown           1
# 977995  unknown  unknown           1
# 978000  unknown   female           1

# %%
for mins, df in all_close_duplicates.items():
    out_path = os.path.join(data_dir, f"close_duplicates_{mins}min.csv")
    df.to_csv(out_path, index=False)
    print(f"Saved {len(df)} records to {out_path}")
# Out:
# Saved 43707 records to data\ssusa\close_duplicates_1min.csv
# Saved 241400 records to data\ssusa\close_duplicates_5min.csv
# Saved 312867 records to data\ssusa\close_duplicates_10min.csv
# Saved 353389 records to data\ssusa\close_duplicates_15min.csv
# Saved 423405 records to data\ssusa\close_duplicates_30min.csv
# Saved 494008 records to data\ssusa\close_duplicates_60min.csv

# %%
all_close_duplicates[30].head(50)
# Out:
#         Year            Project Camera_Trap_Array  \
# 977986  2023  Snapshot USA 2023       CoteauRanch
# 977987  2023  Snapshot USA 2023       CoteauRanch
# 978000  2023  Snapshot USA 2023       CoteauRanch
# 978006  2023  Snapshot USA 2023       CoteauRanch
# 978001  2023  Snapshot USA 2023       CoteauRanch
# 978012  2023  Snapshot USA 2023       CoteauRanch
# 978005  2023  Snapshot USA 2023       CoteauRanch
# 978008  2023  Snapshot USA 2023       CoteauRanch
# 978014  2023  Snapshot USA 2023       CoteauRanch
# 978010  2023  Snapshot USA 2023       CoteauRanch
# 568516  2022  Snapshot USA 2022           Afognak
# 570081  2022  Snapshot USA 2022           Afognak
# 569535  2022  Snapshot USA 2022           Afognak
# 572415  2022  Snapshot USA 2022           Afognak
# 569063  2022  Snapshot USA 2022           Afognak
# 568394  2022  Snapshot USA 2022           Afognak
# 569487  2022  Snapshot USA 2022           Afognak
# 571074  2022  Snapshot USA 2022           Afognak
# 571550  2022  Snapshot USA 2022           Afognak
# 567742  2022  Snapshot USA 2022           Afognak
# 570553  2022  Snapshot USA 2022           Afognak
# 571860  2022  Snapshot USA 2022           Afognak
# 607585  2022  Snapshot USA 2022           Afognak
# 607835  2022  Snapshot USA 2022           Afognak
# 572253  2022  Snapshot USA 2022           Afognak
# 572412  2022  Snapshot USA 2022           Afognak
# 599382  2022  Snapshot USA 2022           Afognak
# 599705  2022  Snapshot USA 2022           Afognak
# 569794  2022  Snapshot USA 2022           Afognak
# 571489  2022  Snapshot USA 2022           Afognak
# 568102  2022  Snapshot USA 2022           Afognak
# 568870  2022  Snapshot USA 2022           Afognak
# 569179  2022  Snapshot USA 2022           Afognak
# 570442  2022  Snapshot USA 2022           Afognak
# 567803  2022  Snapshot USA 2022           Afognak
# 571074   cervidae  odocoileus    hemionus             mule deer  unknown
# 571550   cervidae  odocoileus    hemionus             mule deer  unknown
# 567742   cervidae  odocoileus    hemionus             mule deer  unknown
# 570553   cervidae  odocoileus    hemionus             mule deer  unknown
# 571860   cervidae  odocoileus    hemionus             mule deer  unknown
# 607585  leporidae       lepus  americanus         snowshoe hare  unknown
# 607835  leporidae       lepus  americanus         snowshoe hare  unknown
# 572253   cervidae  odocoileus    hemionus             mule deer  unknown
# 572412   cervidae  odocoileus    hemionus             mule deer  unknown
# 599382    canidae      vulpes      vulpes               red fox  unknown
# 599705    canidae      vulpes      vulpes               red fox  unknown
# 569794   cervidae  odocoileus    hemionus             mule deer  unknown
# 571489   cervidae  odocoileus    hemionus             mule deer  unknown
# 568102   cervidae  odocoileus    hemionus             mule deer  unknown
# 568870   cervidae  odocoileus    hemionus             mule deer  unknown
# 569179   cervidae  odocoileus    hemionus             mule deer  unknown
# 570442   cervidae  odocoileus    hemionus             mule deer  unknown
# 567803   cervidae  odocoileus    hemionus             mule deer  unknown
# 569656   cervidae  odocoileus    hemionus             mule deer  unknown
# 561945  hominidae        homo     sapiens  human-camera trapper  unknown
# 560994  hominidae        homo     sapiens  human-camera trapper  unknown
# 607650  leporidae       lepus  americanus         snowshoe hare  unknown
# 607513  leporidae       lepus  americanus         snowshoe hare  unknown
# 571220   cervidae  odocoileus    hemionus             mule deer  unknown
# 570080   cervidae  odocoileus    hemionus             mule deer  unknown
# 569015   cervidae  odocoileus    hemionus             mule deer  unknown
# 568838   cervidae  odocoileus    hemionus             mule deer  unknown
# 571384   cervidae  odocoileus    hemionus             mule deer  unknown
# 568507   cervidae  odocoileus    hemionus             mule deer  unknown
# 568278   cervidae  odocoileus    hemionus             mule deer  unknown
# 607619  leporidae       lepus  americanus         snowshoe hare  unknown
# 607479  leporidae       lepus  americanus         snowshoe hare  unknown
# 607869  leporidae       lepus  americanus         snowshoe hare  unknown
#
#             Sex  Group_Size
# 977986  unknown           2
# 977987  unknown           3
# 978000   female           1
# 978006  unknown           1
# 978001   female           1
# 978012  unknown           1
# 978005     male           1
# 978008  unknown           1
# 978014  unknown           3
# 978010  unknown           1
# 568516  unknown           1
# 570081  unknown           1
# 569535  unknown           2
# 572415  unknown           1
# 569063  unknown           1
# 568394  unknown           1
# 569487  unknown           1
# 571074  unknown           1
# 571550  unknown           1
# 567742  unknown           1
# 570553  unknown           1
# 571860  unknown           1
# 607585  unknown           1
# 607835  unknown           1
# 572253  unknown           1
# 572412  unknown           1
# 599382  unknown           1
# 599705  unknown           1
# 569794  unknown           1
# 571489  unknown           1
# 568102  unknown           1
# 568870  unknown           1
# 569179  unknown           1
# 570442  unknown           1
# 567803  unknown           3
# 569656  unknown           1
# 561945  unknown           2
# 560994  unknown           2
# 607650  unknown           1
# 607513  unknown           1
# 571220  unknown           2
# 570080  unknown           1
# 569015  unknown           1
# 568838  unknown           1
# 571384  unknown           2
# 568507  unknown           1
# 568278  unknown           1
# 607619  unknown           1
# 607479  unknown           1
# 607869  unknown           1
